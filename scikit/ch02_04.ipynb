# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-np.pi,np.pi,200)
C,S = np.cos(x),np.sin(x)
plt.plot(x,C)
plt.plot(x,S)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-np.pi,np.pi,200)
C,S = np.cos(x),np.sin(x)
plt.plot(x,C,color='blue',linewidth=2.0,linestyle='-')
plt.plot(x,S,color='red',linewidth=2.0,linestyle='-')
plt.xlim(x.min()*1.1,x.max()*1.1)
plt.ylim(C.min()*1.1,C.max()*1.1)
plt.xticks((-np.pi,-np.pi/2,np.pi/2,np.pi),(r'$-\pi$',r'$-\pi/2$',r'$+\pi/2$',r'$+\pi$'))
plt.yticks([-1,-0.5,0,0.5,1])
# axis
ax = plt.gca() # get current axis
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom') # 刻度显示位置
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

#plt.legend(loc='upper left') # 铭牌位置

t = 2 * np.pi / 3
plt.plot([t,t],[0,np.cos(t)],color='blue',linewidth=1.5,linestyle='--')
plt.scatter([t,],[np.cos(t),],50,color='blue')
plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',xy=(t,np.cos(t)),
            xycoords='data',
            xytext=(-90,-50),
            textcoords='offset points',
            fontsize=16,
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=.2"))
plt.plot([t,t],[0,np.sin(t)],color='red',linewidth=1.5,linestyle='--')
plt.scatter([t,],[np.sin(t),],50,color='red')   # 50 point size
plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
            xy=(t,np.sin(t)),   # 标注位置   箭头尖端
            xycoords='data',    # 使用轴域数据坐标系
            xytext=(+10,+30),   # 文本位置 表示从标注点x轴方向上增加10，y轴方向上增加30的位置
            textcoords='offset points',  # 'offset points'标注的内容从xy设置的点进行偏移xytext  'data':标注内容为xytext的绝对坐标
            fontsize=16,
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=.2"))


# 刻度标签字体
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    # 避免曲线覆盖刻度标识，在刻度标签上增加一个半透明的方框作为背景
    label.set_bbox(dict(facecolor='white',edgecolor='none',alpha=0.1))

plt.show()
